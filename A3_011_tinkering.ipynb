# %%
# Import libraries
import pandas as pd
import numpy as np

from datetime import datetime
import regex as re

from surprise import Dataset
from surprise import Reader
from surprise import NormalPredictor
from surprise import accuracy
from surprise.model_selection import cross_validate
from surprise.model_selection import PredefinedKFold
from surprise.model_selection import train_test_split

from utilities import data_basic_utility as databasic

import nltk
from nltk.corpus import stopwords
from nltk.util import ngrams

# %%
print(str(len(stopwords.words("english"))))

print(sorted(stopwords.words("english")))

# %% [markdown]
# ## File Details
#
# To start with, this is basically just a copy paste of the surprise normal sample from Week 12.

# %% [markdown]
# # Assignment 3 -- Recommendation Systems
#
# * The final challenge is much like Assignment 2 -- but scoped appropriately for the time and your current abilities.
# * It is ratings prediction, just like the movielens recommendations we have seen and many other similar problems.
# * The features created are based on Beer Reviews from experts on a website.
# * Each beer has been scored between 0 and 5 (on a real scale, so 2.75 or 3.5 is OK).
# * The official measure is Mean Average Error (MAE) which is pretty intuitive to work with. Everything supports is and it is easy to interpret.
# * A set of features have been created based on the reviewer, the written review, and information about the Beer being reviewed.
# * Not all features have to be used, and you can easily create new features using the data if you like.
# * The features included are:
#
# ![title](Images/A3Features.png)
#
# * Sizes of the files are:
# |Size | File|
# |---|---|
# | 1.9G | features.tsv |
# | 88B  | header-features.tsv|
# | 48B  | header.tsv |
# | 15M  | test.tsv |
# | 50M  | train.tsv |
# | 16M |  val.tsv |

# %%
filePrefix = "A3_01_surprisenormal1"
baseDataDir = "C:/Development/Data/COSC2670/Assignment3/A3data/"
subrunDir = "subruns/"
seed = databasic.get_random_seed()

# %%
# # RowID  BeerID  ReviewerID  BeerName  BeerType  Label
# #df_train = pd.read_csv(baseDataDir + 'train_wk12.tsv',sep='\t',
# df_train = pd.read_csv(baseDataDir + 'train_200k.tsv',sep='\t',
#                          names=['RowID','BeerID','ReviewerID',
#                                   'BeerName','BeerType','rating'])


# #df_vali = pd.read_csv(baseDataDir + 'val_wk12.tsv',sep='\t',
# df_vali = pd.read_csv(baseDataDir + 'vali_200k.tsv',sep='\t',
#                          names=['RowID','BeerID','ReviewerID',
#                                   'BeerName','BeerType','rating'])
# df_vali.head(10)

# %%
# RowID BrewerID ABV DayofWeek Month DayofMonth Year TimeOfDay Gender Birthday Text Lemmatized POS_Tag
# df_features = pd.read_csv(baseDataDir + 'features-top500.tsv',sep='\t', names=['RowID','BrewerID','ABV','DayofWeek','Month',
df_features = pd.read_csv(baseDataDir + 'features_200k.tsv',sep='\t', names=['RowID','BrewerID','ABV','DayofWeek','Month',
# df_features = pd.read_csv(baseDataDir + 'features.tsv',sep='\t', names=['RowID','BrewerID','ABV','DayofWeek','Month',
                                                                 'DayofMonth','Year','TimeOfDay','Gender',
                                                                 'Birthday','Text','Lemmatized','POS_Tag'])

df_features.head(10)

# %%
del df_features["ABV"]
del df_features["DayofWeek"]
del df_features["Month"]
del df_features["DayofMonth"]
del df_features["Year"]
del df_features["TimeOfDay"]
del df_features["Gender"]

# %% [markdown]
# Look at Birthday and do formatting

# %%
def convertBirthdayToAge(input):
  if input.lower() == "unknown":
    return 0
  elif "," not in input:
    return 0
  else:
    tokens = input.split(",")
    year = int(tokens[1])
    age = datetime.now().year - year
    if age > 0:
      return age
    else:
      return 0

# %%
df_features[df_features["Birthday"] != "unknown"].head(50)
# Out:
#      RowID  BrewerID      Birthday  \
# 4       22      1075  Oct 14, 1983
# 8       26      1075  Nov 24, 1974
# 9       27      1075  Oct 10, 1988
# 13      31      1075  Aug 23, 1986
# 14      32      1075  Dec 13, 1978
# 20      38      1075   Feb 3, 1970
# 25      45      1075  Jul 25, 1984
# 26      46      1075  Nov 25, 1978
# 33      53      1075  Jun 29, 1973
# 35      55      1075  Dec 16, 1976
# 37      57      1075   Sep 4, 1982
# 38      58      1075  Nov 20, 1984
# 39      59      1075        May 20
# 41      61      1075  Feb 11, 1982
# 43      63      1075   Sep 2, 1975
# 44      64      1075  Oct 12, 1976
# 46      66      1075   Sep 8, 1982
# 49      69      1075  Jul 21, 1978
# 50      70      1075       July 15
# 51      71      1075  Feb 27, 1987
# 52      72      1075  Oct 23, 1984
# 55      75      1075   Mar 6, 1983
# 57      77      1075   Mar 6, 1986
# 60      80      1075   Oct 3, 1979
# 61      81      1075  Jul 25, 1984
# 62      82      1075  Apr 23, 1984
# 63      83      1075     January 3
# 66      86      1075   May 2, 1971
# 68      88      1075  Apr 22, 1985
# 69      89      1075  Feb 19, 1987
# 70      90      1075  May 31, 1985
# 71      91      1075  Dec 16, 1976
# 75      95      1075  Sep 16, 1972
# 76      96      1075  Feb 27, 1981
# 77      97      1075      March 28
# 81     101      1075  Sep 30, 1972
# 82     102      1075   May 8, 1979
# 85     105      1075      March 14
# 86     106      1075  Apr 20, 1955
# 89     109      1075  Nov 25, 1978
# 94     114      1075  September 30
# 96     116      1075   December 31
# 102    123      1075  Oct 31, 1951
# 106    127      1075  Jun 22, 1983
# 107    128      1075  Sep 22, 1978
# 109    130      1075  Aug 24, 1978
# 113    134      1075    December 9
# 115    136      1075       April 3
# 118    139      1075  Aug 22, 1984
# 119    140      1075  Jul 15, 1986
#
#                                                   Text  \
# 4    This is my first rauchbier . Pours a burnt amb...
# 8    Poured a slightly cloudy deep amber/red color ...
# 9    Big thanks to N2168 for knocking this off my w...
# 13   A - Semi aggressive pour produces a 1-1/2 fing...
# 14                                               Look
# 20   A-Bright , crystal clear , copper with a mediu...
# 25   Pours a rich burnt caramel hue with some deep ...
# 26   On draught at The Beer Stein , Rauch r Bock is...
# 33   I shared this bottle with tenderbranson69 , pi...
# 35                                                  A
# 37   This beer pours a very clear and attractive sh...
# 38                                 22 oz . bomber , A
# 39   A nice ` surprise ' tap at Bailey 's ; grabbed...
# 41   12 oz . can poured into a pint glass . I reall...
# 43   Received this can through Beer Powerball . I a...
# 44   355 ml can bought from Beersofeurope.com ... P...
# 46   Orangeish with a peach head . Smell was hoppy ...
# 49   I 'm really enjoying the variety of quality br...
# 50   12 oz . can , poured into a tulip . See-thru d...
# 51   Pours a deep shade of gold with a fluffy ecru ...
# 52   Pours a clear golden color with a slight orang...
# 55   Poured into pint glass . A - reminiscent of a ...
# 57   Pours a crisp clear pale gold color with a sma...
# 60   Pours a clear gold with some amber hues . Thre...
# 61   pours a crystal-clear light golden hue with le...
# 62            Poured from a can into a pint glass . A
# 63   Thanks to thirstyhophead , who introduced me t...
# 66   Pours out a pale straw like color with a bubbl...
# 68   Can from Beer Run , Charlottesville , VA , enj...
# 69   Pours a pale golden hue with a substantial flu...
# 70   12oz can into nonic . Very pale golden hue wit...
# 71                                                  A
# 75   Poured from a 12oz can into a 20oz imperial pi...
# 76   I wanted to like this beer . I really did . I ...
# 77   I bought a six-pack of Caldera Pale Ale at a g...
# 81   The Caldera Pale Ale poured an clear orange hu...
# 82   Drank on tap at Old Town Pizza in Portland in ...
# 85   Vacationing in Oregon . Little bottleshop has ...
# 86   Pours very nice dark golden yellow color , nic...
# 89   12 oz . can poured into a nonic , the Caldera ...
# 94   Hazy yellow ... taste is not bad , but I would...
# 96   What a classic pale ale , sent courtesy of unc...
# 102  Wow ... when was the last time I drank a beer ...
# 106                                                 A
# 107            In pursuit of the perfect camping beer
# 109  Craft brew in a can . There 's probably a reas...
# 113  12oz bottle into pint glass . Pours a slightly...
# 115                                                 A
# 118  12oz can into a Duvel tulip . No date , but I ...
# 119                 Poured into pint glass from can A
#
#                                             Lemmatized  \
# 4    this be my first rauchbier . pour a burn amber...
# 8    pour a slightly cloudy deep amber/red color wi...
# 9    big thanks to n2168 for knock this off my want...
# 13   a - Semi aggressive pour produce a 1-1/2 finge...
# 14                                               look
# 20   a-bright , crystal clear , copper with a mediu...
# 25   pour a rich burn caramel hue with some deep am...
# 26   on draught at the Beer Stein , Rauch be Bock b...
# 33   I share this bottle with tenderbranson69 , pic...
# 35                                                  a
# 37   this beer pour a very clear and attractive sha...
# 38                                 22 oz . bomber , a
# 39   a nice ` surprise ' tap at Bailey 's ; grab a ...
# 41   12 oz . can pour into a pint glass . I really ...
# 43   receive this can through Beer Powerball . I be...
# 44   355 ml can buy from Beersofeurope.com ... pour...
# 46   Orangeish with a peach head . smell be hoppy ....
# 49   I be really enjoy the variety of quality brew ...
# 50   12 oz . can , pour into a tulip . See-thru dee...
# 51   pour a deep shade of gold with a fluffy ecru h...
# 52   pour a clear golden color with a slight orange...
# 55   pour into pint glass . a - reminiscent of a pi...
# 57   pour a crisp clear pale gold color with a smal...
# 60   pour a clear gold with some amber hue . three ...
# 61   pour a crystal-clear light golden hue with lem...
# 62              pour from a can into a pint glass . a
# 63   thanks to thirstyhophead , who introduce I to ...
# 66   pour out a pale straw like color with a bubbly...
# 68   can from Beer Run , Charlottesville , VA , enj...
# 69   pour a pale golden hue with a substantial fluf...
# 70   12oz can into nonic . very pale golden hue wit...
# 71                                                  a
# 75   pour from a 12oz can into a 20oz imperial pint...
# 76   I want to like this beer . I really do . I lov...
# 77   I buy a six-pack of Caldera Pale Ale at a groc...
# 81   the Caldera Pale Ale pour a clear orange hue w...
# 82   drink on tap at Old Town Pizza in Portland in ...
# 85   vacation in Oregon . little bottleshop have Or...
# 86   pour very nice dark golden yellow color , nice...
# 89   12 oz . can pour into a nonic , the Caldera Pa...
# 94   hazy yellow ... taste be not bad , but I would...
# 96   what a classic pale ale , send courtesy of unc...
# 102  wow ... when be the last time I drink a beer t...
# 106                                                 a
# 107            in pursuit of the perfect camping beer
# 109  craft brew in a can . there be probably a reas...
# 113  12oz bottle into pint glass . pour a slightly ...
# 115                                                 a
# 118  12oz can into a Duvel tulip . no date , but I ...
# 119                   pour into pint glass from can a
#
#                                                POS_Tag  Age
# 4    DT VBZ PRP$ JJ NN . VBZ DT VBN NN . JJ NN . NN...   38
# 8    VBD DT RB JJ JJ VBN NN IN DT JJ NN NN IN NN . ...   47
# 9    JJ NNS IN NN IN VBG DT RP PRP$ NNS . VBN IN DT...   33
# 13   DT HYPH NNP JJ VBP VBZ DT JJ NN RB JJ JJ NN WD...   35
# 14                                                 VB    43
# 20   NN , NN JJ , NN IN DT JJ JJ NN WDT RB VBZ IN D...   51
# 25   VBZ DT JJ VBN NN NN IN DT JJ NN NNS : NN IN DT...   37
# 26   IN NN IN DT NNP NNP , NNP VBP NNP VBZ JJ JJ IN...   43
# 33   PRP VBD DT NN IN NN , VBD RP IN NNP POS IN NNP...   48
# 35                                                 DT    45
# 37   DT NN VBZ DT RB JJ CC JJ NN IN NN NN . RB RBR ...   39
# 38                                    CD NN . NN , DT    37
# 39   DT JJ `` NN '' NN IN NNP POS : VBD DT CD NN . ...    0
# 41   CD NN . MD VBD IN DT NN NN . PRP RB VBP NNS IN...   39
# 43   VBN DT MD IN NNP NNP . PRP VBP RB JJ IN PRP VB...   46
# 44   CD NN MD VBN IN NNP NFP VBD DT JJ JJ NN IN DT ...   45
# 46   NNP IN DT NN NN . NN VBD JJ . NN VBD JJ , RB R...   39
# 49   PRP VBP RB VBG DT NN IN NN NNS IN DT MD PRP VB...   43
# 50   CD NN . MD , VBD IN DT NN . NNP JJ NN NN IN DT...    0
# 51   VBZ DT JJ NN IN NN IN DT JJ NN NN . DT NN VBZ ...   34
# 52   VBZ DT JJ JJ NN IN DT JJ NN NN . DT CD NN JJ J...   37
# 55   VBN IN NN NN . DT HYPH JJ IN DT NN JJR IN DT N...   38
# 57   VBZ DT JJ JJ JJ NN NN IN DT JJ NN WDT VBZ RB R...   35
# 60   VBZ DT JJ NN IN DT NN NNS . CD SYM NNS IN JJ N...   42
# 61   VBZ DT JJ NN JJ NN IN NN CC NN NNS . DT JJ JJ ...   37
# 62                      VBN IN DT MD IN DT NN NN . DT    37
# 63   NN IN NN , WP VBD PRP IN DT NNS IN DT NN NN , ...    0
# 66   VBZ RP DT JJ NN IN NN IN DT RB CD NN RB JJ NN ...   50
# 68   MD IN NNP NNP , NNP , NNP , VBD IN NN IN NNP N...   36
# 69   VBZ DT JJ JJ NN IN DT JJ JJ NN WDT VBZ IN DT N...   34
# 70   NN MD IN JJ . RB JJ JJ NN IN DT JJ NN . DT CD ...   36
# 71                                                 DT    45
# 75                VBN IN DT NN MD IN DT JJ JJ NN . DT    49
# 76   PRP VBD TO VB DT NN . PRP RB VBD . PRP VBP DT ...   40
# 77   PRP VBD DT NN IN NNP NNP NNP IN DT NN NN . VBN...    0
# 81   DT NNP NNP NNP VBD DT JJ NN NN IN DT NN NN NN ...   49
# 82      VBD IN NN IN NNP NNP NNP IN NNP IN NN NN . DT    42
# 85   VBG IN NNP . JJ NN VBZ NNP VBN NNS IN DT NN . ...    0
# 86   NNS RB JJ JJ JJ JJ NN , JJ NN , JJ CD NN JJ JJ...   66
# 89   CD NN . MD VBD IN DT JJ , DT NNP NNP NNP VBZ D...   43
# 94   JJ JJ NFP NN VBZ RB JJ , CC PRP VBP VB PRP$ JJ...    0
# 96   WDT DT JJ JJ NN , VBD NN IN JJ IN DT NN NN . C...    0
# 102  UH , WRB VBD DT JJ NN PRP VBD DT NN WDT VBD IN...   70
# 106                                                DT    38
# 107                              IN NN IN DT JJ NN NN    43
# 109  NN NN IN DT NN . EX VBZ RB DT NN WRB PRP VBZ R...   43
# 113  JJ NN IN NN NN . VBZ DT RB JJ JJ NN NN IN JJ N...    0
# 115                                                DT     0
# 118  NN MD IN DT NNP NN . DT NN , CC PRP VBP PRP VB...   37
# 119                             VBN IN NN NN IN MD DT    35

# %%
df_features["Age"] = df_features.apply(lambda x: convertBirthdayToAge(x["Birthday"]), axis=1)

df_features.head(20)
# Out:
#     RowID  BrewerID      Birthday  \
# 0      18      1075       unknown
# 1      19      1075       unknown
# 2      20      1075       unknown
# 3      21      1075       unknown
# 4      22      1075  Oct 14, 1983
# 5      23      1075       unknown
# 6      24      1075       unknown
# 7      25      1075       unknown
# 8      26      1075  Nov 24, 1974
# 9      27      1075  Oct 10, 1988
# 10     28      1075       unknown
# 11     29      1075       unknown
# 12     30      1075       unknown
# 13     31      1075  Aug 23, 1986
# 14     32      1075  Dec 13, 1978
# 15     33      1075       unknown
# 16     34      1075       unknown
# 17     35      1075       unknown
# 18     36      1075       unknown
# 19     37      1075       unknown
#
#                                                  Text  \
# 0   Pours a murky light brown with a 1 inch fizzy ...
# 1   Faint sudsy head with some with some dissipati...
# 2   A new arrival to the West TN area ... Pours qu...
# 3   Sampled 10/30/11 - Transferring the notes . A ...
# 4   This is my first rauchbier . Pours a burnt amb...
# 5                                                  A
# 6   Pours a mahogany color , rich , with a tan hea...
# 7   Pours light caramel brown with reddish highlig...
# 8   Poured a slightly cloudy deep amber/red color ...
# 9   Big thanks to N2168 for knocking this off my w...
# 10  On tap last night at the Caldera Tap House . P...
# 11  22 oz . Think I picked this up in Chicago Binn...
# 12  Poured into a 1/2 liter stein a deep rich ambe...
# 13  A - Semi aggressive pour produces a 1-1/2 fing...
# 14                                              Look
# 15  Bottleshare from Darthkostrizer with BHOBS and...
# 16  Amber to yeloowcolored , was expecting darker ...
# 17  Pours a brilliant black with ruby tones and a ...
# 18  I have been thinking of picking up a bottle of...
# 19  `` Warning , this beer has an intense smoke fl...
#
#                                            Lemmatized  \
# 0   pour a murky light brown with a 1 inch fizzy t...
# 1   faint sudsy head with some with some dissipate...
# 2   a new arrival to the West TN area ... pour qui...
# 3   sample 10/30/11 - transfer the note . a ruby p...
# 4   this be my first rauchbier . pour a burn amber...
# 5                                                  a
# 6   pour a mahogany color , rich , with a tan head...
# 7   pour light caramel brown with reddish highligh...
# 8   pour a slightly cloudy deep amber/red color wi...
# 9   big thanks to n2168 for knock this off my want...
# 10  on tap last night at the caldera tap House . p...
# 11  22 oz . think I pick this up in Chicago Binny ...
# 12  pour into a 1/2 liter stein a deep rich amber/...
# 13  a - Semi aggressive pour produce a 1-1/2 finge...
# 14                                              look
# 15  Bottleshare from Darthkostrizer with BHOBS and...
# 16  Amber to yeloowcolored , be expect darker , ki...
# 17  pour a brilliant black with ruby tone and a 1-...
# 18  I have be think of pick up a bottle of this fo...
# 19  `` warning , this beer have a intense smoke fl...
#
#                                               POS_Tag  Age
# 0   VBZ DT JJ NN JJ IN DT CD NN JJ NN NN WDT VBZ I...    0
# 1   NN JJ NN IN DT IN DT VBG JJ NN . JJ JJ NN . DT...    0
# 2   DT JJ NN IN DT NNP NNP NN , VBZ PDT DT NN JJR ...    0
# 3   VBN CD HYPH VBG DT NNS . DT NN VBP IN DT NN NN...    0
# 4   DT VBZ PRP$ JJ NN . VBZ DT VBN NN . JJ NN . NN...   38
# 5                                                 DT     0
# 6   VBZ DT NN NN , JJ , IN DT JJ NN . DT NN , VBD ...    0
# 7   NNS JJ NN JJ IN JJ NNS . DT JJ JJ NN VBZ RB VB...    0
# 8   VBD DT RB JJ JJ VBN NN IN DT JJ NN NN IN NN . ...   47
# 9   JJ NNS IN NN IN VBG DT RP PRP$ NNS . VBN IN DT...   33
# 10  IN NN JJ NN IN DT NNS VBP NNP . VBZ DT JJ CC J...    0
# 11  CD NN . VB PRP VBD DT RP IN NNP NNP POS NNP NN...    0
# 12  VBN IN DT CD NN NN DT JJ JJ NN IN DT JJ CD NN ...    0
# 13  DT HYPH NNP JJ VBP VBZ DT JJ NN RB JJ JJ NN WD...   35
# 14                                                VB    43
# 15  NNP IN NNP IN NNP CC NN VBZ DT JJ JJ JJ IN DT ...    0
# 16  NNP IN NNP , VBD VBG JJR , NN IN RB VBD DT JJ ...    0
# 17  VBZ DT JJ JJ IN NN NNS CC DT JJ JJ NN . JJ NN ...    0
# 18  PRP VBP VBN VBG IN VBG RP DT NN IN DT IN DT NN...    0
# 19  `` NN , DT NN VBZ DT JJ NN NN . '' NN : `` IN ...    0

# %% [markdown]
# Tinker with NLP preprocessing stuff on Lemmatized

# %%
df_features.loc[0, "Lemmatized"]

# %%
stringTest = df_features.loc[0, :]["Lemmatized"]
lstTokens = stringTest.split(" ")
lstTokens = sorted(lstTokens)
lstTokens

# %%
stopwordsSorted = sorted(stopwords.words("english"))
print(stopwordsSorted)

# %%
lstTokens2 = databasic.filter_by_words_bsearch(lstTokens, stopwordsSorted)
lstTokens2

# %%
def print_top(lstTokens, numberToPrint=5):
  for i in range(numberToPrint):
    print("[" + ",".join(lstTokens[i]) + "]")

# %%
# convert target column into a list of word tokens  
lstTokens = df_features.apply(lambda x: str(x["Lemmatized"]).split(" "), axis=1)
lstTokens = lstTokens.to_list()

# Do Text Preprocessing: 
# remove capitalisation, single letter tokens and stop words
lstTokens = list(map(lambda x: list(map(lambda y: y.lower(), x)), lstTokens))
lstTokens = list(map(lambda x: list(filter(lambda y: len(y) >= 2, x)), lstTokens))

print_top(lstTokens)

# %%
# sort each token list so we can use bsearch
stopwordsSorted = sorted(stopwords.words("english"))  
lstTokens = list(map(lambda x: databasic.filter_by_words_bsearch(x, stopwordsSorted), lstTokens))

# Create variables for the words and vocab. When we update out tokens lists, we will want to recompile our word list and vocabulary to keep it up to date
words, vocab = databasic.createWordsAndVocabForTokenLists(lstTokens)

# Create a term Frequency distribution
term_fd = nltk.FreqDist(words)

# remove single occurrence words
setSingleWords = set(term_fd.hapaxes())
lstSingleWords = sorted(list(setSingleWords))
lstTokens = list(map(lambda x: databasic.filter_by_words_bsearch(x, lstSingleWords), lstTokens))


print_top(lstTokens)

# %%
setTopBigrams = 50
removeTopFrequentTokens = 50


# find the most commong bigrams and join them together to be a single term
if setTopBigrams > 0:
  bigrams = ngrams(words, n = 2)
  fdbigram = nltk.FreqDist(bigrams)
  mostFreqBigrams = fdbigram.most_common(setTopBigrams)    
  print(mostFreqBigrams)

# %%
lstWorking = lstTokens.copy()
print_top(lstWorking)

# %%
if setTopBigrams > 0:
  # Convert the bigrams to a list of bigram strings (with spaces)
  rep_patterns = list(map(lambda x: x[0], mostFreqBigrams))
  rep_patterns = list(map(lambda x: x[0] + " " + x[1], rep_patterns))

  # Create another list which is the replacements with the
  replacements = list(map(lambda x: x.replace(" ", "_"), rep_patterns))
  
  print(replacements)

  lstWorking = [" ".join(tokens) for tokens in lstWorking] # convert all the token lists back into a single string

  # Loop thought and basically find/replace all the bigrams in the string
  for i in range(0, len(lstWorking)): 
      for j in  range(0,len(rep_patterns)):
          lstWorking[i] = re.sub(rep_patterns[j], replacements[j], lstWorking[i]) # replace with bigram representation 

  lstWorking = [tokens.split(" ") for tokens in lstWorking] # convert back to tokenised lists    


print_top(lstWorking)

# %%
# Look at the most common words, and remove
if removeTopFrequentTokens > 0:
  setMostFreqWords = term_fd.most_common(removeTopFrequentTokens)
  print(setMostFreqWords)
  # lstMostFreqWordsKeys = sorted(list(map(lambda x: x[0], setMostFreqWords)))
  # lstTokens = list(map(lambda x: databasic.filter_by_words_bsearch(x, lstMostFreqWordsKeys), lstTokens))
